# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style("dark", {"axes.facecolor": "black"})

# %%
movie=pd.read_csv("01.csv")

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.columns=["Film","Genre","CritivcRatings","AudienceRatings","Budget","YearOfRelease"]

# %%
movie.head()
movie.Film = movie.Film.astype("category")
movie.Genre = movie.Genre.astype("category")

# %%
n1 = plt.hist(movie.AudienceRatings, bins= 15)

# %%
plt.hist(movie[movie.Genre== "Action"].Budget,bins=20)
plt.hist(movie[movie.Genre== 'Drama'].Budget,bins=20)
plt.hist(movie[movie.Genre== 'Adventure'].Budget,bins=20)
plt.show()

# %%
plt.hist([movie[movie.Genre== "Action"].Budget,movie[movie.Genre== 'Drama'].Budget],bins=20, stacked= True)
plt.show()

# %%
for gwn in movie.Genre.cat.categories:
    print(gwn)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
hard = list()
for gwn in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre==gwn].Budget)
    hard.append(gwn)
sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1,bins=30, stacked=True,rwidth=2,label=hard)
plt.legend()
plt.show()

# %%
import warnings 
warnings.filterwarnings("ignore")
JI = sns.kdeplot(movie.CritivcRatings,movie.AudienceRatings,shade=True,color="RED",shade_lowest=True,weights=33)

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CritivcRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   YearOfRelease    559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
ki = sns.kdeplot(movie.Budget,movie.CritivcRatings)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
ki = sns.kdeplot(movie.Budget,movie.CritivcRatings)

# %%
sns.set_style("dark", {"axes.facecolor": "black"})
f, axs =plt.subplots(3,2,figsize=(15,15))
ki = sns.kdeplot(movie.Budget,movie.CritivcRatings\
                 ,shade=True,shade_lowest=True,cmap="inferno",ax=axs[0,0])
ki1= sns.kdeplot(movie.Budget,movie.CritivcRatings,cmap="cool",ax=axs[0,0])
axs[2,0].hist(movie.AudienceRatings, bins= 15,color="b")
z=sns.violinplot(data=movie\
                 ,x="YearOfRelease",y="CritivcRatings",ax=axs[1,0],palette="cool")
s= sns.boxplot(data=movie,x="YearOfRelease",y="CritivcRatings",ax=axs[1,1],palette="cool")
k1 = sns.kdeplot(movie.CritivcRatings,movie.AudienceRatings,\
                 shade=True,cmap="hot",shade_lowest=True,weights=33,ax=axs[0,1])
k11 = sns.kdeplot(movie.CritivcRatings,movie.AudienceRatings,cmap="cool",ax=axs[0,1])
axs[2,1].hist(movie[movie.Genre== 'Drama'].Budget,bins=20,color="green")
plt.show()

# %%
s= sns.boxplot(data=movie,x="YearOfRelease",y="CritivcRatings")

# %%
a=sns.violinplot(data=movie,x="Genre",y="CritivcRatings")

# %%
f=sns.boxplot(data=movie[movie.Genre=="Drama"],x="YearOfRelease",y="CritivcRatings")

# %%
z=sns.violinplot(data=movie[movie.Genre=="Drama"],x="YearOfRelease",y="CritivcRatings",palette="inferno")
f=sns.boxplot(data=movie[movie.Genre=="Drama"],x="YearOfRelease",y="CritivcRatings",palette="cool")

# %%
g=sns.FacetGrid(movie,row="Genre",col="YearOfRelease",hue="Genre")
g=g.map(plt.scatter,"CritivcRatings","AudienceRatings")
for ax in g.axes.flat:
    ax.plot((100,0),(100,0),c="black",ls="--")
g.add_legend()

# %% [raw]
# list1 = list()
# hard = list()
# for gwn in movie.Genre.cat.categories:
#     list1.append(movie[movie.Genre==gwn].Budget)
#     hard.append(gwn)
# sns.set_style("whitegrid")
# fig, ax = plt.subplots()
# plt.title("movie and Budget",fontsize=35,color="darkblue", fontname="Console")
# plt.xlabel("Budget",fontsize=35,color="g", fontname="Console")
# plt.ylabel("movie of number",fontsize=35,color="r", fontname="Console")
# fig.set_size_inches(11.7, 8.27)
# h = plt.hist(list1,bins=30, stacked=True,rwidth=2,label=hard)
# plt.legend(frameon=True,prop={"size" :20})
# plt.show()

# %%
list1 = list()
hard = list()
for gwn in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre==gwn].Budget)
    hard.append(gwn)
sns.set_style("dark", {"axes.facecolor": "black"})
fig, ax = plt.subplots()
plt.title("movie and Budget",fontsize=35,color="darkblue", fontname="Console")
plt.xlabel("Budget",fontsize=35,color="g", fontname="Console")
plt.ylabel("movie of number",fontsize=35,color="r", fontname="Console")
fig.set_size_inches(11.7, 8.27)
h = plt.hist(list1,bins=30, stacked=True,rwidth=2,label=hard,color={"gold","brown","deepskyblue","slateblue","teal","peru","grey"})
plt.legend(frameon=True,fancybox=True,shadow=True, framealpha=0.5,prop={"size" :20},labelcolor="white")
plt.show()
